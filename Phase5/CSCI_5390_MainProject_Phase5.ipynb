# %% [markdown]
# # **Brett Huffman**
#
# ## **CSCI 5390**
#
# ## Main Project - Phase 5
#
# For this phase, additional images have been added and the model has been changed to a binary classification model.
#
# Credit: The images for this project are from personal library and from Alamy.com covered under their Personal Use license.  Images can only be used for non-commercial purposes.

# %%
# !git clone https://github.com/dicer2000/CSCI_5390
# Out:
# Cloning into 'CSCI_5390'...
# remote: Enumerating objects: 1034, done.
# remote: Counting objects: 100% (1034/1034), done.
# remote: Compressing objects: 100% (1014/1014), done.
# remote: Total 1034 (delta 23), reused 1030 (delta 19), pack-reused 0
# Receiving objects: 100% (1034/1034), 35.38 MiB | 19.58 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# Checkout just the images folder from Github
! ls -l CSCI_5390/MainProject/Images
# Out:
# total 32
# drwxr-xr-x 2 root root  4096 Apr 11 01:26 Ash
# drwxr-xr-x 2 root root  4096 Apr 11 01:26 Cedar
# drwxr-xr-x 2 root root 12288 Apr 11 01:26 Honeysuckle
# drwxr-xr-x 2 root root  4096 Apr 11 01:26 Maple
# drwxr-xr-x 2 root root  4096 Apr 11 01:26 Oak
# -rw-r--r-- 1 root root   593 Apr 11 01:26 removeBlack.py

# %%
# Check out the index file
import pandas as pd
df = pd.read_csv('CSCI_5390/MainProject/TreeImageMaster.csv')
df.head()
# Out:
#    id                   image  treetype
# 0   1  Images/Oak/oak125.jpeg         1
# 1   2  Images/Oak/oak133.jpeg         1
# 2   3    Images/Oak/oak42.jpg         1
# 3   4    Images/Oak/oak56.jpg         1
# 4   5    Images/Oak/oak81.jpg         1

# %%
# Import important libraries
import tensorflow as tf
import numpy as np
import math
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPool2D
from keras import layers, initializers
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
# Generate the Validation And Test Folders

# !mkdir CSCI_5390/MainProject/Training
# !mkdir CSCI_5390/MainProject/Training/Images
# !mkdir CSCI_5390/MainProject/Training/Images/Other
# !mkdir CSCI_5390/MainProject/Training/Images/Honeysuckle

# !mkdir CSCI_5390/MainProject/Validation
# !mkdir CSCI_5390/MainProject/Validation/Images
# !mkdir CSCI_5390/MainProject/Validation/Images/Other
# !mkdir CSCI_5390/MainProject/Validation/Images/Honeysuckle

# !mkdir CSCI_5390/MainProject/Testing
# !mkdir CSCI_5390/MainProject/Testing/Images
# !mkdir CSCI_5390/MainProject/Testing/Images/Other
# !mkdir CSCI_5390/MainProject/Testing/Images/Honeysuckle

# %%
# Randomly move images from the main folder (Training) to Validation
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

df = shuffle(df)
npdata = np.asarray(df)

# 70% Training, 15% Test, 15 Validation
X = npdata[:, :-1]
y = npdata[:, -1]
XTRAIN, XVALID, YTRAIN, YVALID = train_test_split(X, y, test_size=0.3)
XVALID, XTEST, YVALID, YTEST = train_test_split(XVALID, YVALID, test_size=0.5)

# %%
print(XTRAIN.shape, YTRAIN.shape)
print(XTEST.shape, YTEST.shape)
print(XVALID.shape, YVALID.shape)
# Out:
# (557, 2) (557,)
# (120, 2) (120,)
# (120, 2) (120,)

# %%
# Move all the designated files over to the Training folders

for file in XTRAIN[:,1]:
  filename = str(file).strip()
  origFile = "CSCI_5390/MainProject/" + filename
  newFile = ""

  if "Honeysuckle" in filename:
    newFile  = "CSCI_5390/MainProject/Training/" + filename
  else:
    loc = filename.rfind("/")-1
    newFile  = "CSCI_5390/MainProject/Training/Images/Other" + filename[loc+1:]

  print('-----')
  print(filename)
  print(newFile)
  print(origFile)


  # !mv $origFile $newFile

# %%
# Move all the designated files over to the Validation folders

for file in XVALID[:,1]:
  filename = str(file).strip()
  origFile = "CSCI_5390/MainProject/" + filename
  newFile = ""

  if "Honeysuckle" in filename:
    newFile  = "CSCI_5390/MainProject/Validation/" + filename
  else:
    loc = filename.rfind("/")-1
    newFile  = "CSCI_5390/MainProject/Validation/Images/Other" + filename[loc+1:]

  print('-----')
  print(filename)
  print(newFile)
  print(origFile)


  # !mv $origFile $newFile

# %%
# Move all the designated files over to the Test folders
for file in XTEST[:,1]:
  filename = str(file).strip()
  origFile = "CSCI_5390/MainProject/" + filename
  newFile = ""

  if "Honeysuckle" in filename:
    newFile  = "CSCI_5390/MainProject/Testing/" + filename
  else:
    loc = filename.rfind("/")-1
    newFile  = "CSCI_5390/MainProject/Testing/Images/Other" + filename[loc+1:]

  print('-----')
  print(filename)
  print(newFile)
  print(origFile)



  # !mv $origFile $newFile

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Rescale all images by 1./255
my_generator = ImageDataGenerator(rescale=1./255)
#my_generator.fit(XTRAIN)

# %%
# Generator for training dataset
train_dataset = my_generator.flow_from_directory( './CSCI_5390/MainProject/Training/Images', target_size=(150, 150), batch_size=32, class_mode='categorical')
# Out:
# Found 557 images belonging to 2 classes.

# %%
# Generator for validation dataset
validation_dataset = my_generator.flow_from_directory( './CSCI_5390/MainProject/Validation/Images', target_size=(150, 150), batch_size=32, class_mode='categorical')
# Out:
# Found 120 images belonging to 2 classes.

# %%
# Generator for Test dataset
test_dataset = my_generator.flow_from_directory( './CSCI_5390/MainProject/Testing/Images', target_size=(150, 150), batch_size=32, class_mode='categorical')
# Out:
# Found 120 images belonging to 2 classes.

# %%
# Check out the data shapes
for data_batch, labels_batch in train_dataset:
  print("data batch shape:", data_batch.shape)
  print("labels batch shape:", labels_batch.shape)
  break

#print( labels_batch)
# Out:
# data batch shape: (32, 150, 150, 3)
# labels batch shape: (32, 2)

# %%
# Check out the images
for _ in range(1):
    img, label = train_dataset.next()
    print("Shape: ", img.shape)
#    print("Data: ", img) 
    plt.imshow(img[0])
    plt.show()
    plt.imshow(img[1])
    plt.show()
    plt.imshow(img[2])
    plt.show()
    plt.imshow(img[3])
    plt.show()
# Out:
# Shape:  (32, 150, 150, 3)

# %%
# Special Version just to exercise Batch Normalization

from keras import regularizers
from keras.regularizers import L1
# Model - 5 Conv / 1 Dense  ***
# 64 => 16

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="BestModel.hdf5",
        save_best_only=True,
        monitor="val_loss"), # When we have validation data
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        mode='min', 
        patience=40, 
        verbose=1)
]

data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = tf.keras.Input(shape=(150, 150, 3))

x = data_augmentation(inputs)    # Use for With Augmentation

#x = layers.Rescaling(1./255)(inputs)   # Use without Augmentation

x = layers.Conv2D(filters=8, kernel_size=(3, 3), use_bias=False)(inputs)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(filters=16, kernel_size=(3, 3), use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(filters=32, kernel_size=(3, 3), use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=(3, 3), use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=(3, 3), use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)


#x = layers.Dropout(0.25)(x)
x = layers.Flatten()(x)

# , kernel_regularizer=regularizers.l2(0.002)
x = layers.Dense(4, use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

outputs = layers.Dense(2, activation="sigmoid")(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)
  
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
# Version with all Regularization

from keras import regularizers
from keras.regularizers import L1
# Model - 5 Conv / 1 Dense  ***
# 64 => 16

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="BestModel.hdf5",
        save_best_only=True,
        monitor="val_loss"), # When we have validation data
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        mode='min', 
        patience=100, 
        verbose=1)
]

data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = tf.keras.Input(shape=(150, 150, 3))

x = data_augmentation(inputs)    # Use for With Augmentation

#x = layers.Rescaling(1./255)(inputs)   # Use without Augmentation

x = layers.Conv2D(filters=8, kernel_size=(3, 3), use_bias=False)(inputs)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(filters=16, kernel_size=(3, 3), use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Dropout(0.5)(x)

x = layers.Conv2D(filters=32, kernel_size=(3, 3), use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=(3, 3), use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=(3, 3), use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)


x = layers.Dropout(0.5)(x)
x = layers.Flatten()(x)

# , kernel_regularizer=regularizers.l2(0.002)
x = layers.Dense(4,  kernel_regularizer=regularizers.l2(0.002),  use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)

outputs = layers.Dense(2, activation="sigmoid")(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)
  
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
# Original Version 
from keras import regularizers
from keras.regularizers import L1
# Model - 5 Conv / 1 Dense  ***
# 64 => 16

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="BestModel.hdf5",
        save_best_only=True,
        monitor="val_loss"), # When we have validation data
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', 
        mode='min', 
        patience=40, 
        verbose=1)
]

data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = tf.keras.Input(shape=(150, 150, 3))

x = data_augmentation(inputs)    # Use for With Augmentation

#x = layers.Rescaling(1./255)(inputs)   # Use without Augmentation

x = layers.Conv2D(filters=8, kernel_size=(3, 3), activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(filters=16, kernel_size=(3, 3), activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(filters=32, kernel_size=(3, 3), activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=(3, 3), activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=(3, 3), activation="relu")(x)


x = layers.Dropout(0.25)(x)
x = layers.Flatten()(x)

# , kernel_regularizer=regularizers.l2(0.002)
x = layers.Dense(4, activation="relu")(x)
outputs = layers.Dense(2, activation="sigmoid")(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)
  
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
# Let loose the dogs
history = model.fit(train_dataset, validation_data=validation_dataset, epochs=200, callbacks=callbacks)
# Out:
# Epoch 1/200
# 18/18 [==============================] - 3s 98ms/step - loss: 0.7232 - accuracy: 0.6176 - val_loss: 0.7432 - val_accuracy: 0.3417
# Epoch 2/200
# 18/18 [==============================] - 1s 83ms/step - loss: 0.6474 - accuracy: 0.6966 - val_loss: 0.7977 - val_accuracy: 0.3333
# Epoch 3/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.5970 - accuracy: 0.7630 - val_loss: 0.8623 - val_accuracy: 0.3333
# Epoch 4/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.5664 - accuracy: 0.7953 - val_loss: 0.7241 - val_accuracy: 0.3333
# Epoch 5/200
# 18/18 [==============================] - 1s 79ms/step - loss: 0.5336 - accuracy: 0.8366 - val_loss: 0.7736 - val_accuracy: 0.3333
# Epoch 6/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.5181 - accuracy: 0.8492 - val_loss: 0.7679 - val_accuracy: 0.3333
# Epoch 7/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.4920 - accuracy: 0.8618 - val_loss: 0.7752 - val_accuracy: 0.3500
# Epoch 8/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.4670 - accuracy: 0.8977 - val_loss: 0.8586 - val_accuracy: 0.3333
# Epoch 9/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.4529 - accuracy: 0.9048 - val_loss: 0.7570 - val_accuracy: 0.3750
# Epoch 10/200
# 18/18 [==============================] - 2s 82ms/step - loss: 0.4280 - accuracy: 0.9120 - val_loss: 0.6814 - val_accuracy: 0.6667
# Epoch 11/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0.4181 - accuracy: 0.8959 - val_loss: 0.6727 - val_accuracy: 0.7000
# Epoch 12/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.3870 - accuracy: 0.9246 - val_loss: 0.7070 - val_accuracy: 0.4833
# Epoch 13/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.3776 - accuracy: 0.9246 - val_loss: 0.6479 - val_accuracy: 0.7333
# Epoch 14/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0.3476 - accuracy: 0.9354 - val_loss: 0.6367 - val_accuracy: 0.7917
# Epoch 15/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.3399 - accuracy: 0.9408 - val_loss: 0.7126 - val_accuracy: 0.5083
# Epoch 16/200
# 18/18 [==============================] - 2s 85ms/step - loss: 0.3313 - accuracy: 0.9210 - val_loss: 0.5170 - val_accuracy: 0.8083
# Epoch 17/200
# 18/18 [==============================] - 1s 84ms/step - loss: 0.3060 - accuracy: 0.9515 - val_loss: 0.5359 - val_accuracy: 0.8000
# Epoch 18/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.2839 - accuracy: 0.9569 - val_loss: 0.4912 - val_accuracy: 0.8083
# Epoch 19/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.2665 - accuracy: 0.9605 - val_loss: 0.4505 - val_accuracy: 0.8083
# Epoch 20/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0
200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0351 - accuracy: 0.9928 - val_loss: 0.4531 - val_accuracy: 0.8500
# Epoch 79/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0431 - accuracy: 0.9892 - val_loss: 0.3030 - val_accuracy: 0.9083
# Epoch 80/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0401 - accuracy: 0.9874 - val_loss: 0.5358 - val_accuracy: 0.8167
# Epoch 81/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0297 - accuracy: 0.9946 - val_loss: 0.3393 - val_accuracy: 0.9083
# Epoch 82/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0304 - accuracy: 0.9910 - val_loss: 0.5004 - val_accuracy: 0.8500
# Epoch 83/200
# 18/18 [==============================] - 1s 79ms/step - loss: 0.0306 - accuracy: 0.9928 - val_loss: 0.2795 - val_accuracy: 0.9250
# Epoch 84/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0307 - accuracy: 0.9910 - val_loss: 0.3545 - val_accuracy: 0.9000
# Epoch 85/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0293 - accuracy: 0.9982 - val_loss: 0.3058 - val_accuracy: 0.9000
# Epoch 86/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0351 - accuracy: 0.9910 - val_loss: 0.4190 - val_accuracy: 0.8833
# Epoch 87/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0352 - accuracy: 0.9928 - val_loss: 0.2802 - val_accuracy: 0.9250
# Epoch 88/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0227 - accuracy: 0.9964 - val_loss: 0.3466 - val_accuracy: 0.8917
# Epoch 89/200
# 18/18 [==============================] - 1s 79ms/step - loss: 0.0273 - accuracy: 0.9964 - val_loss: 0.8360 - val_accuracy: 0.7917
# Epoch 90/200
# 18/18 [==============================] - 1s 79ms/step - loss: 0.0441 - accuracy: 0.9892 - val_loss: 0.5210 - val_accuracy: 0.8500
# Epoch 91/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0216 - accuracy: 0.9964 - val_loss: 0.7632 - val_accuracy: 0.8250
# Epoch 92/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0365 - accuracy: 0.9910 - val_loss: 0.4010 - val_accuracy: 0.9000
# Epoch 93/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0343 - accuracy: 0.9910 - val_loss: 0.3501 - val_accuracy: 0.9000
# Epoch 94/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0341 - accuracy: 0.9910 - val_loss: 0.4203 - val_accuracy: 0.8667
# Epoch 95/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0423 - accuracy: 0.9856 - val_loss: 0.2827 - val_accuracy: 0.9167
# Epoch 96/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0297 - accuracy: 0.9928 - val_loss: 0.3672 - val_accuracy: 0.9000
# Epoch 97/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0232 - accuracy: 0.9964 - val_loss: 0.3299 - val_accuracy: 0.9000
# Epoch 98/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0.0224 - accuracy: 0.9964 - val_loss: 0.3510 - val_accuracy: 0.9083
# Epoch 99/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0.0548 - accuracy: 0.9892 - val_loss: 0.2561 - val_accuracy: 0.9333
# Epoch 100/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0226 - accuracy: 0.9964 - val_loss: 0.2785 - val_accuracy: 0.9083
# Epoch 101/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0214 - accuracy: 0.9982 - val_loss: 0.6646 - val_accuracy: 0.8417
# Epoch 102/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0364 - accuracy: 0.9928 - val_loss: 0.2934 - val_accuracy: 0.9250
# Epoch 103/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0283 - accuracy: 0.9946 - val_loss: 0.3019 - val_accuracy: 0.9250
# Epoch 104/200
# 18/18 [==============================] - 1s 85ms/step - loss: 0.0654 - accuracy: 0.9820 - val_loss: 0.3071 - val_accuracy: 0.9250
# Epoch 105/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0.1254 - accuracy: 0.9749 - val_loss: 0.3298 - val_accuracy: 0.9000
# Epoch 106/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0234 - accuracy: 0.9946 - val_loss: 0.2646 - val_accuracy: 0.9083
# Epoch 107/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0255 - accuracy: 0.9982 - val_loss: 0.3464 - val_accuracy: 0.9083
# Epoch 108/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0381 - accuracy: 0.9928 - val_loss: 0.3605 - val_accuracy: 0.9083
# Epoch 109/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0362 - accuracy: 0.9910 - val_loss: 0.2969 - val_accuracy: 0.8917
# Epoch 110/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0367 - accuracy: 0.9928 - val_loss: 0.7112 - val_accuracy: 0.7583
# Epoch 111/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0257 - accuracy: 0.9964 - val_loss: 0.2366 - val_accuracy: 0.9250
# Epoch 112/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.3944 - val_accuracy: 0.8833
# Epoch 113/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0295 - accuracy: 0.9946 - val_loss: 0.3007 - val_accuracy: 0.9000
# Epoch 114/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0265 - accuracy: 0.9910 - val_loss: 0.3878 - val_accuracy: 0.8917
# Epoch 115/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0210 - accuracy: 0.9964 - val_loss: 0.3665 - val_accuracy: 0.8917
# Epoch 116/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0271 - accuracy: 0.9982 - val_loss: 0.2521 - val_accuracy: 0.9083
# Epoch 117/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0261 - accuracy: 0.9946 - val_loss: 0.3461 - val_accuracy: 0.9000
# Epoch 118/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0273 - accuracy: 0.9910 - val_loss: 0.3132 - val_accuracy: 0.9167
# Epoch 119/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0297 - accuracy: 0.9928 - val_loss: 0.3639 - val_accuracy: 0.9083
# Epoch 120/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0272 - accuracy: 0.9946 - val_loss: 0.8857 - val_accuracy: 0.7667
# Epoch 121/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0502 - accuracy: 0.9856 - val_loss: 0.7358 - val_accuracy: 0.7833
# Epoch 122/200
# 18/18 [==============================] - 2s 89ms/step - loss: 0.0253 - accuracy: 0.9946 - val_loss: 0.3376 - val_accuracy: 0.9167
# Epoch 123/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0281 - accuracy: 0.9928 - val_loss: 0.2957 - val_accuracy: 0.9000
# Epoch 124/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0430 - accuracy: 0.9874 - val_loss: 0.2828 - val_accuracy: 0.9167
# Epoch 125/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0.0180 - accuracy: 0.9964 - val_loss: 0.3489 - val_accuracy: 0.8833
# Epoch 126/200
# 18/18 [==============================] - 1s 79ms/step - loss: 0.0391 - accuracy: 0.9892 - val_loss: 0.3346 - val_accuracy: 0.9083
# Epoch 127/200
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0202 - accuracy: 0.9982 - val_loss: 0.6857 - val_accuracy: 0.8417
# Epoch 128/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0.0275 - accuracy: 0.9928 - val_loss: 0.3888 - val_accuracy: 0.9083
# Epoch 129/200
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0382 - accuracy: 0.9892 - val_loss: 0.3354 - val_accuracy: 0.9417
# Epoch 130/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0230 - accuracy: 0.9946 - val_loss: 0.2862 - val_accuracy: 0.9417
# Epoch 131/200
# 18/18 [==============================] - 2s 82ms/step - loss: 0.0202 - accuracy: 0.9964 - val_loss: 0.2577 - val_accuracy: 0.9333
# Epoch 132/200
# 18/18 [==============================] - 1s 79ms/step - loss: 0.0475 - accuracy: 0.9874 - val_loss: 2.3762 - val_accuracy: 0.5333
# Epoch 133/200
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0326 - accuracy: 0.9910 - val_loss: 0.3025 - val_accuracy: 0.9000
# Epoch 134/200
# 18/18 [==============================] - 1s 78ms/step - loss: 0.0297 - accuracy: 0.9928 - val_loss: 0.3766 - val_accuracy: 0.8750
# Epoch 135/200
# 18/18 [==============================] - 1s 79ms/step - loss: 0.0188 - accuracy: 0.9982 - val_loss: 0.2633 - val_accuracy: 0.9417
# Epoch 136/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0323 - accuracy: 0.9964 - val_loss: 0.4930 - val_accuracy: 0.8583
# Epoch 137/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0255 - accuracy: 0.9982 - val_loss: 0.3515 - val_accuracy: 0.9167
# Epoch 138/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0371 - accuracy: 0.9910 - val_loss: 0.3383 - val_accuracy: 0.9000
# Epoch 139/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0486 - accuracy: 0.9874 - val_loss: 0.2713 - val_accuracy: 0.9000
# Epoch 140/200
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0340 - accuracy: 0.9874 - val_loss: 0.3556 - val_accuracy: 0.9167
# Epoch 141/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.2437 - val_accuracy: 0.9417
# Epoch 142/200
# 18/18 [==============================] - 2s 90ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.2725 - val_accuracy: 0.9417
# Epoch 143/200
# 18/18 [==============================] - 1s 81ms/step - loss: 0.0237 - accuracy: 0.9946 - val_loss: 0.7195 - val_accuracy: 0.8167
# Epoch 144/200
# 18/18 [==============================] - 2s 83ms/step - loss: 0.0335 - accuracy: 0.9928 - val_loss: 0.4703 - val_accuracy: 0.9000
# Epoch 145/200
# 18/18 [==============================] - 2s 85ms/step - loss: 0.0244 - accuracy: 0.9964 - val_loss: 0.4043 - val_accuracy: 0.8833
# Epoch 146/200
# 18/18 [==============================] - 2s 84ms/step - loss: 0.0287 - accuracy: 0.9946 - val_loss: 0.4048 - val_accuracy: 0.8750
# Epoch 147/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0246 - accuracy: 0.9946 - val_loss: 0.3214 - val_accuracy: 0.9083
# Epoch 148/200
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0314 - accuracy: 0.9928 - val_loss: 0.2959 - val_accuracy: 0.9333
# Epoch 149/200
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.4727 - val_accuracy: 0.8917
# Epoch 149: early stopping

# %%
model.summary()

# %%
# Loads the weights
model.load_weights("BestModel.hdf5")

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "g", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "g", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# demonstration of calculating metrics for a neural network model using sklearn
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
# When using generators, you can calculate precision, recall, F1-score, etc. using the following idea (roughly)
Y = [] # empty list of true labels
P = [] # empty list of predictions


for _ in range(1):
  img, label = test_dataset.next()
  p = model.predict(img)
  Y.extend(label)
  P.extend(p)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(Y, p.round())
precision = precision_score(Y, p.round(), average="macro") # precision_score(Y, p.round())
recall = recall_score(Y, p.round(), average="macro")
f1 = f1_score(Y, p.round(), average="macro")

print('Accuracy: ', accuracy)
print('Precision: ', precision)
print('Recall: ', recall)
print('F1: ', f1)
# Out:
# Accuracy:  0.90625
# Precision:  0.8990384615384616
# Recall:  0.9375
# F1:  0.9175

# %%
while True:pass
